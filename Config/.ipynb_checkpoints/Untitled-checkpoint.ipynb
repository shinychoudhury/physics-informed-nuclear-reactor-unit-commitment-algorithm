# %%
import papermill as pm
import os

path=os.path.abspath(os.getcwd().replace("/Example", ""))

pm.execute_notebook(
    os.path.join(path, "master_UC_nuclear.ipynb"),
    os.path.join(path, "output_master_run.ipynb")
)
# Out:
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# ---------------------------------------------------------------------------
# PapermillExecutionError                   Traceback (most recent call last)
# <ipython-input-5-f894fd84b35e> in <module>
#       4 path=os.path.abspath(os.getcwd().replace("/Example", ""))
#       5
# ----> 6 pm.execute_notebook(
#       7     os.path.join(path, "master_UC_nuclear.ipynb"),
#       8     os.path.join(path, "output_master_run.ipynb")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/papermill/execute.py in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, language, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     126
#     127             # Check for errors first (it saves on error before raising)
# --> 128             raise_for_execution_errors(nb, output_path)
#     129
# ...
